# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# From http://www-personal.umich.edu/~mejn/netdata/

# %%
H = nx.read_gml("power.gml", label = 'id')

# %% [markdown]
# remove any node > 500 to shrink the network

# %%
for i in range(250, 4941):
    H.remove_node(i)

# %% [markdown]
# https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html#networkx.algorithms.components.connected_components

# %%
largest_cc = max(nx.connected_components(H), key=len)
largest_subgraph = H.subgraph(largest_cc).copy()

# %% [markdown]
# 2. Create basic analysis on the graph, including the graph’s diameter, and at least one other metric of your choosing.<br>
# You may either code the functions by hand (to build your intuition and insight), or use functions in an existing package.<br>
# Calculate closness

# %%
print (nx.diameter(largest_subgraph))
print(nx.average_clustering(largest_subgraph))
# Out:
# 19
# 0.05352965747702589

# %% [markdown]
# 3. Use a visualization tool of your choice (Neo4j, Gephi, etc.) to display information.

# %%
nx.draw_networkx(largest_subgraph)
plt.axis("off")
plt.show()

# %% [markdown]
# 4. Please record a short video (~ 5 minutes), and submit a link to the video as part of your homework submission.
